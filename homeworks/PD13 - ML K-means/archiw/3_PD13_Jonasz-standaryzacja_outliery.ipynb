# %% [markdown]
# # JDSZR6, Jonasz Krawczyk
# ## zadanie domowe nr 13

# %% [markdown]
# **treść zadania**

# %% [markdown]
# Na podstawie zbioru https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data dokonaj klasteryzacji różnych rodzajów noclegów oferowanych przez Airbnb. Proponowane zmienne do klasteryzacji:
#
# latitude
# longitude
# Price
# minimum nights
# Number of reviews lub number of reviews per month
# Proszę o wybranie minimum 4 zmiennych. Klasteryzacja pozwoli nam na znalezienie obiektów położonych w podobnym miejscu i o zbliżonych cenach i warunkach. Należy wyznaczyć optymalną liczbę klastrów z graficznym objaśnieniem. Trzeba pamiętać o zachowaniu poprawności założeń (np. standaryzacja zmiennych).

# %% [markdown]
# ---
# ### STANDARYZACJA + OUTLIERY

# %% [markdown]
# ## 1. importy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
import sklearn.metrics
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. analiza danych

# %% [markdown]
# W tym punkcie będę chciał na tyle poeksplorować dane aby je zrozumieć. Zadaniem jest pogrupowanie obiektów; nie ma tu konkretnego targetu (uczenie nienadzorowane).

# %%
df = pd.read_csv('AB_NYC_2019.csv')

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# Myślę, że niepotrzebne są zmienne: 'id', 'name', 'host_id', 'host_name', 'last_review', 'reviews_per_month'. Przy tej okazji dataframe zostanie oczyszczony z NaNów.

# %%
df.drop(
    ['id', 'name', 'host_id', 'host_name', 'last_review', 'reviews_per_month', 'calculated_host_listings_count'],
    axis=1,
    inplace=True)

# %% [markdown]
# Data Frame ma sens dla niezerowej ceny mieszkania i takiego które w ogóle można wynająć (jest dostępne w ciągu nadchodzącego roku). Dodatkowo, ponieważ jest to Air BnB to co do zasady powinno dotyczyć ofert krótkoterminowych. Usunę oferty od Januszy, którzy wrzucają swoje ogłoszenia na każdy portal:

# %%
df = df[df.price > 0]
df = df[df.availability_365 > 0]
df = df[df.minimum_nights < 30]

# %%
df.head()
# Out:
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5           Manhattan   Murray Hill  40.74767  -73.97500  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  availability_365
# 0    149               1                  9               365
# 1    225               1                 45               355
# 2    150               3                  0               365
# 3     89               1                270               194
# 5    200               3                 74               129

# %%
df.duplicated().any()
# Out:
# False

# %%
def value_counter(data_frame, list_of_variables):
    for i in list_of_variables:
        print(data_frame[i].value_counts())
        print()

# %%
variables = ['neighbourhood_group', 'neighbourhood', 'room_type', 'minimum_nights']

# %%
value_counter(df, variables)
# Out:
# Brooklyn         11167
# Manhattan        10962
# Queens            3989
# Bronx              878
# Staten Island      316
# Name: neighbourhood_group, dtype: int64
#
# Bedford-Stuyvesant    2259
# Williamsburg          1889
# Harlem                1566
# Bushwick              1287
# Hell's Kitchen        1149
#                       ...
# Rossville                1
# Willowbrook              1
# Fort Wadsworth           1
# Silver Lake              1
# Richmondtown             1
# Name: neighbourhood, Length: 218, dtype: int64
#
# Entire home/apt    13648
# Private room       12892
# Shared room          772
# Name: room_type, dtype: int64
#
# 1     7741
# 2     7713
# 3     5033
# 4     1958
# 5     1623
# 7     1074
# 6      427
# 29     320
# 14     307
# 10     247
# 28     170
# 15     158
# 20     134
# 21      72
# 8       68
# 25      50
# 9       47
# 12      47
# 13      26
# 18      16
# 11      16
# 24      12
# 26      11
# 27      11
# 16       9
# 17       7
# 22       6
# 19       5
# 23       4
# Name: minimum_nights, dtype: int64

# %% [markdown]
# dość problematyczne jest 'neighbourhood', które w zasadzie ma 218 kategorii

# %%
cat_df = df.select_dtypes(include=['object'])
num_df = df.select_dtypes(exclude=['object'])
print("non numeric:", cat_df.columns)
print()
print("numeric:", num_df.columns)
# Out:
# non numeric: Index(['neighbourhood_group', 'neighbourhood', 'room_type'], dtype='object')
#
# numeric: Index(['latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews',
#        'availability_365'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 10))
data = df.neighbourhood.value_counts()[:10]
x = list(data.index)
y = list(data.values)
x.reverse()
y.reverse()

plt.title("Most Popular Neighbourhood")
plt.ylabel("Neighbourhood Area")
plt.xlabel("Number of guest Who host in this Area")

plt.barh(x, y)
plt.show()

# %%
le = LabelEncoder()
df[cat_df.columns] = df[cat_df.columns].apply(
    lambda col: le.fit_transform(col))

# %%
df.hist(edgecolor="black", linewidth=1.2, figsize=(15, 20))
plt.show()

# %%
plt.figure(figsize=(15, 15))

df_copy1 = df.copy()
df_corr = df_copy1.corr()

color_map = sns.diverging_palette(240, 10, n=10)
mask = np.triu(np.ones_like(df_corr), k=0)
mask = mask[1:, :-1]
corr = df_corr.iloc[1:, :-1].copy()
sns.heatmap(corr,
            mask=mask,
            annot=True,
            fmt=".3f",
            cmap=color_map,
            center=0,
            vmin=-0.293,
            vmax=0.214,
            cbar=False,
            linewidth=2,
            square=True,
            annot_kws={
                'font': 'serif',
                'size': 11.5,
                'color': 'black',
                'fontweight': 'bold'
            })
plt.text(2,
         0,
         'Heatmap of Data correlation',
         fontsize=18,
         fontweight='bold',
         fontfamily='serif')
pass

# %% [markdown]
# nie ma tu zmiennych silnie skorelowanych; spodziewałem się większej zależności ceny od współrzędnych

# %%
nei = df.groupby('neighbourhood_group')['longitude'].agg(['count'])
nei.reset_index(level=0, inplace=True)
plt.pie(nei['count'], labels=nei['neighbourhood_group'])
plt.show()

# %%
plt.figure(figsize=(10, 10))
a = sns.scatterplot(data=df,
                    x='longitude',
                    y='latitude',
                    hue='neighbourhood_group',
                    palette='viridis')
plt.title('Map of airbnb', fontsize=15)
plt.xlabel('Latitude')
plt.ylabel("Longitude")
plt.legend(frameon=False, fontsize=13)

# %% [markdown]
# ktośby powiedział, że właśnie zrobiłem klasteryzację, idę do domu.

# %%
nei = df.groupby('room_type')['latitude'].agg(['count'])
nei.reset_index(level=0, inplace=True)
plt.pie(nei['count'], labels=nei['room_type'])
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.countplot(
    x=df['neighbourhood_group'],
    hue=df['room_type'])
plt.show()

# %%
for column in df:
    plt.figure()
    df.boxplot([column])

# %% [markdown]
# outliery pozostawię dla współrzędnych.

# %% [markdown]
# ## 3. przygotowanie zbioru, ustanowienie modelu

# %% [markdown]
# #### 3.1 outliery

# %%
df.columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'number_of_reviews',
#        'availability_365'],
#       dtype='object')

# %%
cols = [
    'neighbourhood_group', 'neighbourhood', 'room_type', 'price',
    'minimum_nights', 'number_of_reviews', 'availability_365'
]

# %%
Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df[cols] < (Q1 - 1.5 * IQR)) | (df[cols] >
                                           (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# #### 3.2 standaryzacja

# %%
StSc = StandardScaler()

# %%
dfs = df.copy()
dfs = StSc.fit_transform(dfs)
dfs = pd.DataFrame(dfs, columns = df.columns)

# %% [markdown]
# #### 3.3 normalizacja

# %%
# NoSc = MinMaxScaler()

# %%
# dfs = df.copy()
# dfs = NoSc.fit_transform(dfs)
# dfs = pd.DataFrame(dfs, columns = df.columns)

# %%
dfs
# Out:
#        neighbourhood_group  neighbourhood  latitude  longitude  room_type  \
# 0                -0.836564       0.112012 -1.365674  -0.613084   0.762987
# 1                 0.421943       0.394393  0.441687  -0.831783  -1.033454
# 2                 0.421943      -0.096059  1.385132  -0.028542   0.762987
# 3                 0.421943       0.543014  0.340360  -0.663538  -1.033454
# 4                 0.421943       1.494192  1.285338  -0.480329  -1.033454
# ...                    ...            ...       ...        ...        ...
# 20107             0.421943      -0.081197  0.617093  -0.986407   0.762987
# 20108             1.680449       0.067425 -0.618411   2.531776   0.762987
# 20109            -0.836564      -1.299893 -0.837072  -0.182975   0.762987
# 20110            -0.836564      -1.076961 -0.440110   0.138935   0.762987
# 20111             0.421943      -0.081197  0.507932  -0.972787   2.559428
#
#           price  minimum_nights  number_of_reviews  availability_365
# 0      0.373056       -1.038532          -0.551548          1.658894
# 1      1.449141       -1.038532           0.762951          1.578944
# 2      0.387215        0.522468          -0.880173          1.658894
# 3      1.095166        0.522468           1.821853         -0.227913
# 4      0.174830        2.083468           1.055062         -1.211291
# ...         ...             ...                ...               ...
# 20107  0.033240        1.302968          -0.880173         -1.011417
# 20108 -0.816301       -1.038532          -0.880173          0.043915
# 20109 -0.745506       -0.258032          -0.880173         -1.187306
# 20110 -1.170276        1.302968          -0.880173         -0.971442
# 20111 -0.957891       -1.038532          -0.880173         -1.243270
#
# [20112 rows x 9 columns]

# %% [markdown]
# #### 3.4 dla formalności - postawienie modelu

# %%
x = np.array(dfs)
kmeans = KMeans(random_state=997).fit(x)
cluser_labels = kmeans.labels_

# %% [markdown]
# ## 4. wybór optymalnego K

# %%
feat_list_1 = [
    'neighbourhood_group', 'neighbourhood', 'room_type', 'price',
    'minimum_nights', 'number_of_reviews', 'availability_365'
]

# %%
feat_list_2 = [
    'neighbourhood_group', 'neighbourhood', 'room_type',
    'minimum_nights', 
]

# %%
feat_list_3 = ['number_of_reviews', 'price']

# %%
def variance_plotter(feats):
    features = feats
    features.append('longitude')
    features.append('latitude')
    dfv = dfs[features]
    global x
    x = np.array(dfv)
    kmeans = KMeans(random_state=997).fit(x)
    cluser_labels = kmeans.labels_

    k_vec = []
    int_vec = []

    for k in range(2, 15):
        kmeans = KMeans(n_clusters=k, random_state=997).fit(x)
        interia = kmeans.inertia_
        k_vec.append(k)
        int_vec.append(interia)

    plt.figure(figsize=(12, 10))
    plt.title('Wykres sum wariancji klastów')
    plt.plot(k_vec, int_vec, 'bo-')
    plt.xlabel('liczba klastrów')
    plt.ylabel('Suma wariancji klastrów')
    plt.show()

# %%
def map_plotter(clusters):
    kmeans = KMeans(n_clusters=clusters, random_state=997).fit(x)
    cluser_labels = kmeans.labels_
    plt.figure(figsize=(10, 10))
    plt.title('air BnB - clusterization')
    plt.xlabel('latitude-scaled')
    plt.ylabel('longitude-scaled')
    plt.scatter(x[:, -1], x[:, -2], c=cluser_labels, s=20, cmap='Dark2')
    plt.show()
    inertia = "{:,}".format(round(kmeans.inertia_))
    print("clusters inertia :", inertia)

# %%
variance_plotter(feat_list_1)

# %%
map_plotter(10)
# Out:
# clusters inertia : 88,855

# %% [markdown]
# Nie daje się zauważyć stabilizacji wariancji, mapka mogłaby być bardziej czytelna; spróbuję z mniejszą ilością danych.

# %%
variance_plotter(feat_list_2)

# %%
map_plotter(8)
# Out:
# clusters inertia : 45,812

# %% [markdown]
# Znacząco spadła wariancja, chociaż mapka nadal jest zagmatwana. Niemniej jednak kształtuje się już jakaś zależność. Nie jestem przekonany czy 8 klastrów to nie za dużo na określenie typu klienta, na wyczucie może to być 5-6 typów. Spróbuję użyć jeszcze mniej informacji (tj. 4, zgodnie z poleceniem). Dodatkowo wygląda na to, że kilka klastrów się pokrywa

# %%
variance_plotter(feat_list_3)

# %%
map_plotter(5)
# Out:
# clusters inertia : 31,983

# %% [markdown]
# Spadła wariancja i klasteryzacja 'wygląda' dobrze przy mniejszej ilości klastrów.

# %% [markdown]
# ## 5. podsumowanie i wnioski

# %% [markdown]
# Wraz ze spadkiem ilości cech modelu, spada także suma wariancji, znaczy dopasowanie jest lepsze. Na ostatniej mapce ukształtowały się ramy terytorialne podziału rynku.<br>
# Taki model jednak ma małą ilość zmiennych, ledwie cztery, z czego dwie to współrzędne.<br>
# Duże znaczenie na wyniki ma także odpowiedni dobór zestawu cech wejściowych do modelu.<br>
# Model można dopracować na bazie ostatniego tak, aby piąty klaster nie był 'zjedzony' przez pozostałe cztery, zalecałbym także spróbować dodać cechę do listy.
# Wycinanie outlierów nie było dobrym pomysłem, chociaż nie usuwałem ich bezpośrednio ze współrzędnych to i tak część miasta znikęła przez wycinanie z innych zmiennych. Usunięcie outlierów zmniejszyło jednak wariancję (w por. ze zmiennymi standaryzowanymi) 150k-100k, 140k-100k, 90k-60k: czyli o ok. 1/3.

# %% [markdown]
# ## BRUDNOPIS
